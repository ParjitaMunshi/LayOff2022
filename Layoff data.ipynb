# %%
#importing Libraries
import pandas as pd

# %%
#load the dataset
df = pd.read_csv(r"E:\My Project\LayOff2022\layoffs.csv")

# %%
print(df)
# Out:
#             company        location        industry  total_laid_off  \
# 0            Zomato        Gurugram            Food           100.0
# 1           Carvana         Phoenix  Transportation          1500.0
# 2              Nuro     SF Bay Area  Transportation           300.0
# 3             Kavak       Sao Paulo  Transportation             NaN
# 4          Metaplex         Chicago          Crypto             NaN
# ...             ...             ...             ...             ...
# 1646        Service     Los Angeles          Travel             NaN
# 1647   HopSkipDrive     Los Angeles  Transportation             8.0
# 1648    Panda Squad     SF Bay Area        Consumer             6.0
# 1649  Tamara Mellon     Los Angeles          Retail            20.0
# 1650       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off        date     stage        country  funds_raised
# ...

# %%
df.shape
# Out:
# (1651, 9)

# %%
df.isnull()
# Out:
#       company  location  industry  total_laid_off  percentage_laid_off   date  \
# 0       False     False     False           False                False  False
# 1       False     False     False           False                False  False
# 2       False     False     False           False                False  False
# 3       False     False     False            True                 True  False
# 4       False     False     False            True                 True  False
# ...       ...       ...       ...             ...                  ...    ...
# 1646    False     False     False            True                False  False
# 1647    False     False     False           False                False  False
# 1648    False     False     False           False                False  False
# 1649    False     False     False           False                False  False
# 1650    False     False     False           False                 True  False
#
# ...

# %%
df.isna().sum()
# Out:
# company                  0
# location                 0
# industry                 3
# total_laid_off         476
# percentage_laid_off    546
# date                     0
# stage                    4
# country                  0
# funds_raised           115
# dtype: int64

# %%
data = df.fillna(0).head(10)
data
# Out:
#        company         location        industry  total_laid_off  \
# 0       Zomato         Gurugram            Food           100.0
# 1      Carvana          Phoenix  Transportation          1500.0
# 2         Nuro      SF Bay Area  Transportation           300.0
# 3        Kavak        Sao Paulo  Transportation             0.0
# 4     Metaplex          Chicago          Crypto             0.0
# 5  StoryBlocks  Washington D.C.           Media             0.0
# 6         Roku      SF Bay Area           Media           200.0
# 7      Orchard    New York City     Real Estate           180.0
# 8    Homepoint          Phoenix     Real Estate           113.0
# 9         Juni       Gothenburg         Finance            72.0
#
#    percentage_laid_off        date     stage        country  funds_raised
# 0                 0.04  19-11-2022  Series J          India         914.0
# 1                 0.08  18-11-2022       IPO  United States        1600.0
# ...

# %%
data.isna().sum()
# Out:
# company                0
# location               0
# industry               0
# total_laid_off         0
# percentage_laid_off    0
# date                   0
# stage                  0
# country                0
# funds_raised           0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
x = data['total_laid_off']
y = data['company']

# %%
plt.scatter(x,y,c='red')
plt.xlabel('Total Laid Off')
plt.ylabel('Comapny')
plt.title('Company total number of lay off')
plt.show()
